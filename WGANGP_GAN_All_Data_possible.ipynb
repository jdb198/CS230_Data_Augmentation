# %% [markdown]
# Vanilla GAN from this website
#
# https://github.com/Yangyangii/GAN-Tutorial/blob/master/MNIST/VanillaGAN.ipynb
#
# https://github.com/Yangyangii/GAN-Tutorial/blob/master/MNIST/Conditional-GAN.ipynb
#
#
# Combine into a DCGAN - 1D
#
# https://github.com/LixiangHan/GANs-for-1D-Signal/blob/main/dcgan.py

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in c:\python projects\venv\lib\site-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in c:\python projects\venv\lib\site-packages (0.20.1+cu121)
# Requirement already satisfied: filelock in c:\python projects\venv\lib\site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\python projects\venv\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\python projects\venv\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\python projects\venv\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\python projects\venv\lib\site-packages (from torch) (2024.10.0)
# Requirement already satisfied: setuptools in c:\python projects\venv\lib\site-packages (from torch) (75.4.0)
# Requirement already satisfied: sympy==1.13.1 in c:\python projects\venv\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\python projects\venv\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\python projects\venv\lib\site-packages (from torchvision) (1.26.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\python projects\venv\lib\site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python projects\venv\lib\site-packages (from jinja2->torch) (3.0.2)
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
# !pip install torchinfo
from torchinfo import summary
# Out:
# Requirement already satisfied: torchinfo in c:\python projects\venv\lib\site-packages (1.8.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image
import torch.autograd as autograd

# %%
import numpy as np
import datetime
import os, sys
import scipy.io
import scipy.fftpack

# %%
from matplotlib.pyplot import imshow, imsave
# %matplotlib inline

# %%
MODEL_NAME = 'ConditionalWGAN'
DEVICE = 'mps' if torch.backends.mps.is_available() else 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
def to_onehot(x, num_classes=2):
    assert isinstance(x, int) or isinstance(x, (torch.LongTensor, torch.cuda.LongTensor))
    if isinstance(x, int):
        c = torch.zeros(1, num_classes).long()
        c[0][x] = 1
    else:
        x = x.cpu()
        c = torch.LongTensor(x.size(0), num_classes)
        c.zero_()
        c.scatter_(1, x, 1) # dim, index, src value
    return c

# %%
def get_sample_image(G, n_noise=100):
    """
        save sample 100 images
    """
    #img = np.zeros([280, 280])
    for j in range(2):
        c = torch.zeros([10, 2]).to(DEVICE)
        c[:, j] = 1
        z = torch.randn(10, n_noise).to(DEVICE) # number of random noise vectors created = 10
        y_hat = G(z,c).view(10, 3, 1000)
        #result = y_hat.cpu().data.numpy()
        if j == 0: # this is a left movement
          data_left = y_hat.cpu().data.numpy()
        else:
          data_right = y_hat.cpu().data.numpy()
    return data_left, data_right

# %%
class Discriminator(nn.Module):
    """
        Simple Discriminator w/ MLP
    """
    def __init__(self, in_channel=3, input_size = 3000, num_classes=2):
        super(Discriminator, self).__init__()
        self.transform = nn.Sequential(
            nn.Linear(input_size + num_classes, 3000),
            nn.LeakyReLU(0.2),
        )

        self.conv = nn.Sequential(
            nn.Conv1d(in_channel, 512, kernel_size=4, stride=2, padding=1, bias=False),
            #nn.BatchNorm1d(512),
            nn.LeakyReLU(0.2, inplace=True),


            nn.Conv1d(512, 256, kernel_size=3, stride=3, padding=1, bias=False),
            #nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2, inplace=True),

            # state size 456
            nn.Conv1d(256, 128, kernel_size=3, stride=3, padding=1, bias=False),
            #nn.BatchNorm1d(128),
            nn.LeakyReLU(0.2, inplace=True),


            # state size 228
           nn.Conv1d(128, 64, kernel_size=4, stride=4, padding=1, bias=False),
           #nn.BatchNorm1d(64),
           nn.LeakyReLU(0.2, inplace=True),
           nn.AvgPool1d(6),
        )

        self.fc = nn.Sequential(
            nn.Linear(128, 1),
            #nn.Sigmoid(),
        )

    def forward(self, x, c=None):
        # x: (N, 3, 1000), c: (N, 2)
        x, c = x.view(x.size(0), -1), c.float() #c: (N, channels, input), c: (N, num_classes)
        v = torch.cat((x, c), 1) # (n, 3002) adding embedding
        #print(v.shape)
        y_ = self.transform(v) # (N, 3002)
        y_ = y_.view(y_.shape[0], 3 ,1000) # (N, 3, 1000)
       # print(y_.shape)
        y_ = self.conv(y_)
        #print(y_.shape)
        y_ = y_.view(y_.size(0), -1)
        #print(y_.shape)
        y_ = self.fc(y_)
        return y_

# %%
# Define model and inputs
model = Discriminator(in_channel=3, input_size=3000, num_classes=2)
batch_size = 16
input_size = (batch_size, 3, 1000)  # Adjust based on your use case
class_label_size = (batch_size, 2)

# Summarize model
summary(
    model,
    input_size=(input_size, class_label_size),
    col_names=["input_size", "output_size", "num_params", "kernel_size", "mult_adds"],
    depth=3
)
# Out:
# =====================================================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Kernel Shape              Mult-Adds
# =====================================================================================================================================================================
# Discriminator                            [16, 3, 1000]             [16, 1]                   --                        --                        --
# ├─Sequential: 1-1                        [16, 3002]                [16, 3000]                --                        --                        --
# │    └─Linear: 2-1                       [16, 3002]                [16, 3000]                9,009,000                 --                        144,144,000
# │    └─LeakyReLU: 2-2                    [16, 3000]                [16, 3000]                --                        --                        --
# ├─Sequential: 1-2                        [16, 3, 1000]             [16, 64, 2]               --                        --                        --
# │    └─Conv1d: 2-3                       [16, 3, 1000]             [16, 512, 500]            6,144                     [4]                       49,152,000
# │    └─LeakyReLU: 2-4                    [16, 512, 500]            [16, 512, 500]            --                        --                        --
# │    └─Conv1d: 2-5                       [16, 512, 500]            [16, 256, 167]            393,216                   [3]                       1,050,673,152
# │    └─LeakyReLU: 2-6                    [16, 256, 167]            [16, 256, 167]            --                        --                        --
# │    └─Conv1d: 2-7                       [16, 256, 167]            [16, 128, 56]             98,304                    [3]                       88,080,384
# │    └─LeakyReLU: 2-8                    [16, 128, 56]             [16, 128, 56]             --                        --                        --
# │    └─Conv1d: 2-9                       [16, 128, 56]             [16, 64, 14]              32,768                    [4]                       7,340,032
# │    └─LeakyReLU: 2-10                   [16, 64, 14]              [16, 64, 14]              --                        --                        --
# │    └─AvgPool1d: 2-11                   [16, 64, 14]              [16, 64, 2]               --                        [6]                       --
# ├─Sequential: 1-3                        [16, 128]                 [16, 1]                   --                        --                        --
# │    └─Linear: 2-12                      [16, 128]                 [16, 1]                   129                       --                        2,064
# =====================================================================================================================================================================
# Total params: 9,539,561
# Trainable params: 9,539,561
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.34
# =====================================================================================================================================================================
# Input size (MB): 0.19
# Forward/backward pass size (MB): 39.66
# Params size (MB): 38.16
# Estimated Total Size (MB): 78.01
# =====================================================================================================================================================================

# %%
class Generator(nn.Module):
    """
        Convolutional Generator for MNIST
    """
    def __init__(self, input_size=100, condition_size=2):
        super(Generator, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size+condition_size, 2048 *3),
            nn.ReLU(),
        )
        self.conv = nn.Sequential(
            # input: 4 by 4, output: 7 by 7
            nn.ConvTranspose1d(2048, 1024, 5, stride=5, padding=2, bias=False),
            #nn.BatchNorm1d(1024),
            nn.ReLU(),

            nn.ConvTranspose1d(1024, 512, 5, stride=5, padding=2, bias=False),
            #nn.BatchNorm1d(512),
            nn.ReLU(),
            # input: 7 by 7, output: 14 by 14
            nn.ConvTranspose1d(512, 256, 5, stride=5, padding=2, bias=False),
            #nn.BatchNorm1d(256),
            nn.ReLU(),
            # input: 14 by 14, output: 28 by 28
            nn.ConvTranspose1d(256, 3, 4, stride=4, padding=2, bias=False),
            nn.Tanh(),
        )

    def forward(self, x, c):
        # x: (N, 100), c: (N, 2)
        x, c = x.view(x.size(0), -1), c.float() # may not need
        v = torch.cat((x, c), 1) # v: (N, 102)
        #print(v.shape)
        y_ = self.fc(v)
        #print(y_.shape)
        y_ = y_.view(y_.size(0), 2048, 3)
        #print(y_.shape)
        y_ = self.conv(y_) # (N, 28, 28)
        return y_

# %%
# Define model and inputs
model = Generator(input_size=100, condition_size=2)
batch_size = 16
input_size = (batch_size, 100)  # Adjust based on your use case
class_label_size = (batch_size, 2)

# Summarize model
summary(
    model,
    input_size=(input_size, class_label_size),
    col_names=["input_size", "output_size", "num_params", "kernel_size", "mult_adds"],
    depth=3
)
# Out:
# =====================================================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Kernel Shape              Mult-Adds
# =====================================================================================================================================================================
# Generator                                [16, 100]                 [16, 3, 1000]             --                        --                        --
# ├─Sequential: 1-1                        [16, 102]                 [16, 6144]                --                        --                        --
# │    └─Linear: 2-1                       [16, 102]                 [16, 6144]                632,832                   --                        10,125,312
# │    └─ReLU: 2-2                         [16, 6144]                [16, 6144]                --                        --                        --
# ├─Sequential: 1-2                        [16, 2048, 3]             [16, 3, 1000]             --                        --                        --
# │    └─ConvTranspose1d: 2-3              [16, 2048, 3]             [16, 1024, 11]            10,485,760                [5]                       1,845,493,760
# │    └─ReLU: 2-4                         [16, 1024, 11]            [16, 1024, 11]            --                        --                        --
# │    └─ConvTranspose1d: 2-5              [16, 1024, 11]            [16, 512, 51]             2,621,440                 [5]                       2,139,095,040
# │    └─ReLU: 2-6                         [16, 512, 51]             [16, 512, 51]             --                        --                        --
# │    └─ConvTranspose1d: 2-7              [16, 512, 51]             [16, 256, 251]            655,360                   [5]                       2,631,925,760
# │    └─ReLU: 2-8                         [16, 256, 251]            [16, 256, 251]            --                        --                        --
# │    └─ConvTranspose1d: 2-9              [16, 256, 251]            [16, 3, 1000]             3,072                     [4]                       49,152,000
# │    └─Tanh: 2-10                        [16, 3, 1000]             [16, 3, 1000]             --                        --                        --
# =====================================================================================================================================================================
# Total params: 14,398,464
# Trainable params: 14,398,464
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 6.68
# =====================================================================================================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 14.18
# Params size (MB): 57.59
# Estimated Total Size (MB): 71.78
# =====================================================================================================================================================================

# %%
n_noise = 100

# %%
D = Discriminator().to(DEVICE)
G = Generator(n_noise).to(DEVICE)

# %%
what_data_to_use = 'SINE_COSINE' # EEG_ALL, EEG_ONE, SINE_COSINE

# %%
if what_data_to_use == 'EEG_All':
  data =  np.empty((1000, 3, 3240)) # empty np array that concatenates all of the trials
  labels = [] #np.empty((3240,1))
  list_of_files = ['B0901T.mat', 'B0902T.mat', 'B0903T.mat', 'B0801T.mat', 'B0802T.mat', 'B0803T.mat','B0701T.mat', 'B0702T.mat', 'B0703T.mat',
                  'B0601T.mat', 'B0602T.mat', 'B0603T.mat', 'B0501T.mat', 'B0502T.mat', 'B0503T.mat', 'B0401T.mat', 'B0402T.mat', 'B0403T.mat',
                  'B0301T.mat', 'B0302T.mat', 'B0303T.mat', 'B0201T.mat', 'B0202T.mat', 'B0203T.mat', 'B0101T.mat', 'B0102T.mat', 'B0103T.mat']

  for idx in range(len(list_of_files)):
    target_tmp = scipy.io.loadmat(list_of_files[idx])
    data_tmp = target_tmp['data']
    label_tmp = target_tmp['label']
    data[:,:, idx*120:(idx+1)*120] = data_tmp
    for i in range(len(label_tmp)):
      if label_tmp[i] == 1.0:
        labels.append(0)
      else:
        labels.append(1)


  data = np.transpose(data, (2, 1, 0))
  label = np.array(labels).reshape(3240, 1)
elif what_data_to_use == 'EEG_ONE':
  data =  np.empty((1000, 3, 3240)) # empty np array that concatenates all of the trials
  labels = [] #np.empty((3240,1))
  list_of_files = ['B0901T.mat', 'B0902T.mat', 'B0903T.mat', 'B0801T.mat', 'B0802T.mat', 'B0803T.mat','B0701T.mat', 'B0702T.mat', 'B0703T.mat',
                  'B0601T.mat', 'B0602T.mat', 'B0603T.mat', 'B0501T.mat', 'B0502T.mat', 'B0503T.mat', 'B0401T.mat', 'B0402T.mat', 'B0403T.mat',
                  'B0301T.mat', 'B0302T.mat', 'B0303T.mat', 'B0201T.mat', 'B0202T.mat', 'B0203T.mat', 'B0101T.mat', 'B0102T.mat', 'B0103T.mat']

  for idx in range(len(list_of_files)):
    target_tmp = scipy.io.loadmat(list_of_files[idx])
    data_tmp = target_tmp['data']
    label_tmp = target_tmp['label']
    data[:,:, idx*120:(idx+1)*120] = data_tmp
    for i in range(len(label_tmp)):
      if label_tmp[i] == 1.0:
        labels.append(0)
      else:
        labels.append(1)

  data = np.transpose(data, (2, 1, 0))
  label = np.array(labels).reshape(3240, 1)
else: # sine  & cosine
  data = []
  temps = []
  labels = []
  t = np.linspace(0, 4, num=1000)

  for i in range(3240):
    indicator = np.random.randint(0,2)
    for j in range(3):
      variation_add = np.random.uniform(-.1,.1)
      if indicator == 0:  #left movement
        temps.append( (0.5 + variation_add) *np.sin(50*t) + 0.5)
        data += temps
        if j == 0:
          labels.append(0)
      else:
        temps.append( (0.5+variation_add) *np.cos(50*t) + 0.5)
        if j==0:
          labels.append(1)

  data = np.array(temps).reshape(3240,3,1000)
  label = np.array(labels).reshape(3240,1)

# normalize the data to be between [0, 1]
mins = []
maxes = []

for i in range(data.shape[0]):
  for j in range(data.shape[1]):
    mins.append(np.min(data[i, j, :]))
    maxes.append(np.max(data[i, j, :]))
max_data = np.average(maxes)
min_data = np.average(mins)
for i in range(data.shape[0]):
  for j in range(data.shape[1]):
    data[i, j, :] = (data[i, j, :] - min_data) / (max_data - min_data)

# %%
class Sine_Cosine_Dataset(Dataset):
  def __init__(self, data, labels, transform=None):
    self.data = data
    self.labels = labels
    self.transform=transform

  def __len__(self):
    return len(self.data)

  def __getitem__(self, index):
    data = self.data[index]
    label = self.labels[index]

    if self.transform:
      data = self.transform(data)

    return data, label

# %%
dataset = Sine_Cosine_Dataset(data, labels)

# %%
batch_size = 64
condition_size=2

# %%
data_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
criterion = nn.BCELoss()
D_opt = torch.optim.Adam(D.parameters(), lr=0.0001, betas=(0., 0.9))
G_opt = torch.optim.Adam(G.parameters(), lr=0.0001, betas=(0., 0.9))

# %%
max_epoch = 25 # need more than 10 epochs for training generator
step = 0
p_coeff = 10 # lambda
n_critic = 5

# %%
D_labels = torch.ones(batch_size, 1).to(DEVICE) # Discriminator Label to real
D_fakes = torch.zeros(batch_size, 1).to(DEVICE) # Discriminator Label to fake

# %%
if not os.path.exists('samples'):
    os.makedirs('samples')

# %%
Discriminator_loss = []
Generator_loss = []
steps = []
for epoch in range(max_epoch):
    for idx, (images, labels) in enumerate(data_loader):
        D.zero_grad()
        ## Training Discriminator
        # Real data
        x = images.to(DEVICE).float()
        y = labels.view(batch_size, 1)
        y = to_onehot(y).to(DEVICE)

        # Sampling
        z = torch.randn(batch_size, n_noise).to(DEVICE)
        x_fake = G(z, y)

        # Gradient Penalty (e.g. gradients w.r.t x_penalty)
        eps = torch.rand(batch_size, 1, 1).to(DEVICE) # x shape: (64, 1, 28, 28)
        x_penalty = eps*x + (1-eps)*x_fake
        x_penalty = x_penalty.view(x_penalty.size(0), -1)
        p_outputs = D(x_penalty, y)
        xp_grad = autograd.grad(outputs=p_outputs, inputs=x_penalty, grad_outputs=D_labels,
                                create_graph=True, retain_graph=True, only_inputs=True)
        grad_penalty = p_coeff * torch.mean(torch.pow(torch.norm(xp_grad[0], 2, 1) - 1, 2))

        # Wasserstein loss
        x_outputs = D(x, y)
        z_outputs = D(x_fake, y)
        D_x_loss = torch.mean(x_outputs)
        D_z_loss = torch.mean(z_outputs)
        D_loss = D_z_loss - D_x_loss + grad_penalty

        D_loss.backward()
        D_opt.step()
        if step % n_critic == 0:
            D.zero_grad()
            G.zero_grad()
            # Training Generator
            z = torch.randn(batch_size, n_noise).to(DEVICE)
            z_outputs = D(G(z, y), y)
            G_loss = -torch.mean(z_outputs)

            G_loss.backward()
            G_opt.step()
        step += 1
        #if step % 500 == 0:
    print('Epoch: {}/{}, Step: {}, D Loss: {}, G Loss: {}'.format(epoch, max_epoch, step, D_loss.item(), G_loss.item()))
    Discriminator_loss.append(D_loss.item())
    Generator_loss.append(G_loss.item())

        #if step % 1000 == 0:
        #    G.eval()
        #    img = get_sample_image(G, n_noise)
        #    imsave('samples/{}_step{:05d}.jpg'.format(MODEL_NAME, step), img, cmap='gray')
        #    G.train()
        #step += 1
# Out:
# C:\Python Projects\venv\Lib\site-packages\torch\autograd\graph.py:825: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\cuda\CublasHandlePool.cpp:135.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch: 0/25, Step: 50, D Loss: -15.577972412109375, G Loss: -9.318309783935547
# Epoch: 1/25, Step: 100, D Loss: -1.1832096576690674, G Loss: -5.478786468505859
# Epoch: 2/25, Step: 150, D Loss: -3.29758620262146, G Loss: -4.652866840362549
# Epoch: 3/25, Step: 200, D Loss: -5.007656574249268, G Loss: -3.447154998779297
# Epoch: 4/25, Step: 250, D Loss: -17.633846282958984, G Loss: -3.6288959980010986
# Epoch: 5/25, Step: 300, D Loss: -17.629528045654297, G Loss: 6.484999656677246
# Epoch: 6/25, Step: 350, D Loss: -16.39423370361328, G Loss: -7.034516334533691
# Epoch: 7/25, Step: 400, D Loss: -16.165939331054688, G Loss: 2.309968948364258
# Epoch: 8/25, Step: 450, D Loss: -11.697935104370117, G Loss: -4.609188079833984
# Epoch: 9/25, Step: 500, D Loss: -8.232657432556152, G Loss: -4.566726207733154
# Epoch: 10/25, Step: 550, D Loss: -7.868416786193848, G Loss: -1.833613634109497
# Epoch: 11/25, Step: 600, D Loss: -6.002884387969971, G Loss: -12.854990005493164
# Epoch: 12/25, Step: 650, D Loss: -5.836359977722168, G Loss: -8.408608436584473
# Epoch: 13/25, Step: 700, D Loss: -7.167285442352295, G Loss: -19.242862701416016
# Epoch: 14/25, Step: 750, D Loss: -8.967116355895996, G Loss: 1.6593685150146484
# Epoch: 15/25, Step: 800, D Loss: -6.7541327476501465, G Loss: -8.350296974182129
# Epoch: 16/25, Step: 850, D Loss: -7.546907901763916, G Loss: -14.388509750366211
# Epoch: 17/25, Step: 900, D Loss: -7.194924354553223, G Loss: 0.8712636232376099
# Epoch: 18/25, Step: 950, D Loss: -7.714459419250488, G Loss: -5.945980072021484
# Epoch: 19/25, Step: 1000, D Loss: -7.194173336029053, G Loss: -17.186725616455078
# Epoch: 20/25, Step: 1050, D Loss: -7.545294284820557, G Loss: 0.9171830415725708
# Epoch: 21/25, Step: 1100, D Loss: -8.019775390625, G Loss: 1.473955512046814
# Epoch: 22/25, Step: 1150, D Loss: -10.784360885620117, G Loss: -5.808460235595703
# Epoch: 23/25, Step: 1200, D Loss: -8.174129486083984, G Loss: -8.191986083984375
# Epoch: 24/25, Step: 1250, D Loss: -8.33785629272461, G Loss: -5.8305840492248535

# %%
import matplotlib.pyplot as plt
print(steps)
plt.plot(Discriminator_loss, 'k')
plt.plot(Generator_loss, 'cornflowerblue')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.title('WGAN Losses')
plt.legend(['Discriminator Loss', 'Generator Loss'])
plt.show
# Out:
# []
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
G.eval()
data_left, data_right = get_sample_image(G, n_noise)
x = np.linspace(0, 4, num=1000)

# %%
#choose right and left
stop_button = 0
while stop_button < 3:
    for i in label:
        if i == 0:
            y_left = data[i, 0,:].squeeze()
            stop_button +=1
        else:
            y_right = data[i,0,:].squeeze()
            stop_button +=1

# %%
# sampling rate
sr = 250
# sampling interval
ts = 1.0/sr
t = np.arange(0,4,ts)
x = y_left

# %%
from numpy.fft import fft, ifft

X_left = fft(y_left)
left_fft_gen = fft(data_left[9,1,:])
N = len(X_left)
n = np.arange(N)
T = N/sr
freq = n/T

plt.figure(figsize = (12, 6))
plt.subplot(121)

plt.stem(freq, np.abs(X_left), 'k', \
         markerfmt=" ", basefmt="-b", label='EEG Data')
plt.stem(freq, np.abs(left_fft_gen), 'cornflowerblue', \
         markerfmt=" ", basefmt="-b", label='EEG Data - Generated')
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude |X(freq)|')
plt.xlim(0.1, 250)
plt.title('FFT Left')
plt.legend()
plt.ylim(0, 60)

plt.subplot(122)
plt.plot(t, ifft(left_fft_gen), 'cornflowerblue', label='EEG Data - Generated')
plt.plot(t, ifft(X_left), 'k', label='EEG Data')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.title('Signal Left')
plt.legend()
plt.show()
# Out:
# C:\Python Projects\venv\Lib\site-packages\matplotlib\cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# C:\Python Projects\venv\Lib\site-packages\matplotlib\cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
from numpy.fft import fft, ifft

X_right = fft(y_right)
right_fft_gen = fft(data_right[9,1,:])
N = len(X_right)
n = np.arange(N)
T = N/sr
freq = n/T

plt.figure(figsize = (12, 6))
plt.subplot(121)

plt.stem(freq, np.abs(X_right), 'k', \
         markerfmt=" ", basefmt="-b", label='EEG Data')
plt.stem(freq, np.abs(right_fft_gen), 'cornflowerblue', \
         markerfmt=" ", basefmt="-b", label='EEG Data - Generated')
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude |X(freq)|')
plt.xlim(0.1, 250)
plt.title('FFT Right')
plt.legend()
plt.ylim(0, 60)

plt.subplot(122)
plt.plot(t, ifft(right_fft_gen), 'cornflowerblue', label='EEG Data - Generated')
plt.plot(t, ifft(X_right), 'k', label='EEG Data')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.title('Signal Right')
plt.legend()
plt.show()
